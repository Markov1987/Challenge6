# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import Citipy
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bf896ab30f63598ff1d37dc69d8d31ee

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | brainerd
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | caluquembe
# Processing Record 5 of Set 1 | harper
# Processing Record 6 of Set 1 | marystown
# Processing Record 7 of Set 1 | virginia beach
# Processing Record 8 of Set 1 | gualeguaychu
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | san carlos de bariloche
# Processing Record 11 of Set 1 | sur
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | kathu
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | kavaratti
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | paredon
# Processing Record 26 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | komsomolskiy
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | zapolyarnyy
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | dosso
# Processing Record 35 of Set 1 | kedrovyy
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | daltenganj
# Processing Record 38 of Set 1 | buala
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | mercedes
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 1 | dallas
# Processing Record 48 of Set 1 | marsh harbour
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | chifeng
# Processing Record 2 of Set 2 | catuday
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | tendo
# Processing Record 5 of Set 2 | nouadhibou
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | rio grande
# Processing Record 9 of Set 2 | quelimane
# Processing Record 10 of Set 2 | sibolga
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | abu samrah
# Processing Record 14 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | sokolka
# Processing Record 17 of Set 2 | north bend
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | tambopata
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | quepos
# Processing Record 23 of Set 2 | santo andre
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | itupiranga
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | hami
# Processing Record 29 of Set 2 | vao
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 2 | pontian kecil
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | wanning
# Processing Record 37 of Set 2 | olden
# Processing Record 38 of Set 2 | coihaique
# Processing Record 39 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 2 | vryburg
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | kirovsk
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | suhbaatar
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | paytug
# City not found. Skipping...
# Processing Record 48 of Set 2 | byron bay
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | san juan
# Processing Record 3 of Set 3 | palora
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | broken hill
# Processing Record 7 of Set 3 | warri
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | ferkessedougou
# Processing Record 10 of Set 3 | merauke
# Processing Record 11 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 3 | arcelia
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | lianzhou
# Processing Record 15 of Set 3 | praia
# Processing Record 16 of Set 3 | oussouye
# Processing Record 17 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | manali
# Processing Record 20 of Set 3 | shingu
# Processing Record 21 of Set 3 | alofi
# Processing Record 22 of Set 3 | nevelsk
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | baruun-urt
# Processing Record 26 of Set 3 | kautokeino
# Processing Record 27 of Set 3 | calabozo
# Processing Record 28 of Set 3 | bereda
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 30 of Set 3 | jambi
# Processing Record 31 of Set 3 | bilma
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | huaihua
# Processing Record 34 of Set 3 | miri
# Processing Record 35 of Set 3 | yulara
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | bugulma
# Processing Record 38 of Set 3 | sistranda
# Processing Record 39 of Set 3 | collie
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | yanam
# Processing Record 45 of Set 3 | olutanga
# Processing Record 46 of Set 3 | olinda
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | severo-kurilsk
# Processing Record 49 of Set 3 | vero beach
# Processing Record 50 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 4 | fasa
# Processing Record 2 of Set 4 | chapais
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | san vicente
# Processing Record 5 of Set 4 | mabaruma
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | jefferson city
# Processing Record 9 of Set 4 | rocha
# Processing Record 10 of Set 4 | qitaihe
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | beringovskiy
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | dickinson
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | adrar
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 4 | hithadhoo
# Processing Record 20 of Set 4 | saint-joseph
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | buraydah
# Processing Record 23 of Set 4 | zhizdra
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | vostok
# Processing Record 27 of Set 4 | seoul
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | ixtapa
# Processing Record 30 of Set 4 | nome
# Processing Record 31 of Set 4 | paamiut
# Processing Record 32 of Set 4 | linhares
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | shibetsu
# Processing Record 35 of Set 4 | riberalta
# Processing Record 36 of Set 4 | charlestown
# Processing Record 37 of Set 4 | pimentel
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | abu zabad
# Processing Record 43 of Set 4 | del rio
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | lavrentiya
# Processing Record 46 of Set 4 | dhrangadhra
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | zhigansk
# Processing Record 49 of Set 4 | ihosy
# Processing Record 50 of Set 4 | suntar
# Processing Record 1 of Set 5 | sao filipe
# Processing Record 2 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 5 | bari sadri
# Processing Record 4 of Set 5 | ust-kuyga
# Processing Record 5 of Set 5 | yaan
# Processing Record 6 of Set 5 | tulun
# Processing Record 7 of Set 5 | harnosand
# Processing Record 8 of Set 5 | santa barbara
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | ahipara
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | abha
# Processing Record 15 of Set 5 | mohpa
# Processing Record 16 of Set 5 | turayf
# Processing Record 17 of Set 5 | banda aceh
# Processing Record 18 of Set 5 | iquique
# Processing Record 19 of Set 5 | olafsvik
# Processing Record 20 of Set 5 | hervey bay
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | nyurba
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | kommunisticheskiy
# Processing Record 25 of Set 5 | scottsbluff
# Processing Record 26 of Set 5 | roswell
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 5 | jakarta
# Processing Record 31 of Set 5 | kemijarvi
# Processing Record 32 of Set 5 | moree
# Processing Record 33 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 35 of Set 5 | fez
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | bonavista
# Processing Record 38 of Set 5 | torbay
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | kuytun
# Processing Record 41 of Set 5 | half moon bay
# Processing Record 42 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 5 | nishihara
# Processing Record 44 of Set 5 | batagay
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | kodinsk
# Processing Record 47 of Set 5 | kirovskiy
# Processing Record 48 of Set 5 | forbes
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | dong hoi
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 6 | saint simons
# Processing Record 5 of Set 6 | camacha
# Processing Record 6 of Set 6 | nioro
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | tema
# Processing Record 9 of Set 6 | bhigvan
# Processing Record 10 of Set 6 | antsohihy
# Processing Record 11 of Set 6 | leningradskiy
# Processing Record 12 of Set 6 | haines junction
# Processing Record 13 of Set 6 | katherine
# Processing Record 14 of Set 6 | dingle
# Processing Record 15 of Set 6 | namatanai
# Processing Record 16 of Set 6 | kasama
# Processing Record 17 of Set 6 | raudeberg
# Processing Record 18 of Set 6 | sortland
# Processing Record 19 of Set 6 | yelizovo
# Processing Record 20 of Set 6 | lecce
# Processing Record 21 of Set 6 | alta floresta
# Processing Record 22 of Set 6 | north platte
# Processing Record 23 of Set 6 | avera
# Processing Record 24 of Set 6 | iqaluit
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | ironton
# Processing Record 27 of Set 6 | huarmey
# Processing Record 28 of Set 6 | diamantino
# Processing Record 29 of Set 6 | port hedland
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | mana
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | yumen
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | aksu
# Processing Record 36 of Set 6 | cam ranh
# Processing Record 37 of Set 6 | gweta
# Processing Record 38 of Set 6 | omboue
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | kahului
# Processing Record 41 of Set 6 | weligama
# Processing Record 42 of Set 6 | bratsk
# Processing Record 43 of Set 6 | kroya
# Processing Record 44 of Set 6 | tame
# Processing Record 45 of Set 6 | ribeira grande
# Processing Record 46 of Set 6 | saurimo
# Processing Record 47 of Set 6 | la palma
# Processing Record 48 of Set 6 | thinadhoo
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | fuling
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | viransehir
# Processing Record 4 of Set 7 | ekhabi
# Processing Record 5 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 7 | carutapera
# Processing Record 7 of Set 7 | oistins
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | yeppoon
# Processing Record 10 of Set 7 | baykalsk
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | unity
# Processing Record 13 of Set 7 | marawi
# Processing Record 14 of Set 7 | aktau
# Processing Record 15 of Set 7 | tual
# Processing Record 16 of Set 7 | nerchinskiy zavod
# Processing Record 17 of Set 7 | upernavik
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | mizdah
# Processing Record 20 of Set 7 | majene
# Processing Record 21 of Set 7 | nokaneng
# Processing Record 22 of Set 7 | tigil
# Processing Record 23 of Set 7 | prainha
# Processing Record 24 of Set 7 | hun
# Processing Record 25 of Set 7 | oliveira
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | oskarshamn
# Processing Record 29 of Set 7 | san policarpo
# Processing Record 30 of Set 7 | puro
# Processing Record 31 of Set 7 | ndioum
# Processing Record 32 of Set 7 | laguna
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | hokitika
# Processing Record 35 of Set 7 | lufilufi
# Processing Record 36 of Set 7 | ambon
# Processing Record 37 of Set 7 | kranjska gora
# Processing Record 38 of Set 7 | straumen
# Processing Record 39 of Set 7 | kinsale
# Processing Record 40 of Set 7 | robertsport
# Processing Record 41 of Set 7 | katsuura
# Processing Record 42 of Set 7 | inta
# Processing Record 43 of Set 7 | westport
# Processing Record 44 of Set 7 | gat
# Processing Record 45 of Set 7 | preston
# Processing Record 46 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | bonfim
# Processing Record 49 of Set 7 | ust-omchug
# Processing Record 50 of Set 7 | elk point
# Processing Record 1 of Set 8 | tuatapere
# Processing Record 2 of Set 8 | honiara
# Processing Record 3 of Set 8 | ukiah
# Processing Record 4 of Set 8 | palauig
# Processing Record 5 of Set 8 | fort-shevchenko
# Processing Record 6 of Set 8 | bassila
# Processing Record 7 of Set 8 | beloha
# Processing Record 8 of Set 8 | yusva
# City not found. Skipping...
# Processing Record 9 of Set 8 | palana
# Processing Record 10 of Set 8 | kasongo-lunda
# Processing Record 11 of Set 8 | mikhaylovka
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | kieta
# Processing Record 14 of Set 8 | tadine
# Processing Record 15 of Set 8 | mirnyy
# Processing Record 16 of Set 8 | portel
# Processing Record 17 of Set 8 | vila do maio
# Processing Record 18 of Set 8 | alyangula
# Processing Record 19 of Set 8 | kibre mengist
# Processing Record 20 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 8 | ilulissat
# Processing Record 22 of Set 8 | bundibugyo
# Processing Record 23 of Set 8 | teahupoo
# Processing Record 24 of Set 8 | corinto
# Processing Record 25 of Set 8 | mackay
# Processing Record 26 of Set 8 | natal
# Processing Record 27 of Set 8 | mucuri
# Processing Record 28 of Set 8 | kon tum
# Processing Record 29 of Set 8 | gizo
# Processing Record 30 of Set 8 | losino-petrovskiy
# Processing Record 31 of Set 8 | tromso
# Processing Record 32 of Set 8 | mananara
# Processing Record 33 of Set 8 | bakchar
# Processing Record 34 of Set 8 | smidovich
# Processing Record 35 of Set 8 | belmonte
# Processing Record 36 of Set 8 | cockburn town
# Processing Record 37 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 8 | colac
# Processing Record 39 of Set 8 | churapcha
# Processing Record 40 of Set 8 | sao felix do xingu
# Processing Record 41 of Set 8 | kuching
# Processing Record 42 of Set 8 | payakumbuh
# Processing Record 43 of Set 8 | gorontalo
# Processing Record 44 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 45 of Set 8 | floro
# Processing Record 46 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 8 | kamenka
# Processing Record 48 of Set 8 | finschhafen
# Processing Record 49 of Set 8 | chara
# Processing Record 50 of Set 8 | broome
# Processing Record 1 of Set 9 | marsa matruh
# Processing Record 2 of Set 9 | turinskaya sloboda
# Processing Record 3 of Set 9 | puerto del rosario
# Processing Record 4 of Set 9 | nadvoitsy
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | high level
# Processing Record 7 of Set 9 | el dorado
# Processing Record 8 of Set 9 | biloela
# Processing Record 9 of Set 9 | quatre cocos
# Processing Record 10 of Set 9 | syracuse
# Processing Record 11 of Set 9 | knysna
# Processing Record 12 of Set 9 | portland
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | thaton
# Processing Record 15 of Set 9 | gra liyia
# Processing Record 16 of Set 9 | bella union
# Processing Record 17 of Set 9 | daudnagar
# Processing Record 18 of Set 9 | arevashogh
# Processing Record 19 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 9 | constitucion
# Processing Record 21 of Set 9 | presidencia roque saenz pena
# Processing Record 22 of Set 9 | walvis bay
# Processing Record 23 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 9 | yucca valley
# Processing Record 25 of Set 9 | general cepeda
# Processing Record 26 of Set 9 | maragogi
# Processing Record 27 of Set 9 | la ciotat
# Processing Record 28 of Set 9 | comendador
# Processing Record 29 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 30 of Set 9 | marang
# Processing Record 31 of Set 9 | port blair
# Processing Record 32 of Set 9 | tome
# Processing Record 33 of Set 9 | koumac
# Processing Record 34 of Set 9 | greenville
# Processing Record 35 of Set 9 | mugumu
# Processing Record 36 of Set 9 | acari
# Processing Record 37 of Set 9 | maumere
# Processing Record 38 of Set 9 | sept-iles
# Processing Record 39 of Set 9 | karatuzskoye
# Processing Record 40 of Set 9 | selje
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | moron
# Processing Record 43 of Set 9 | cutervo
# Processing Record 44 of Set 9 | erenhot
# Processing Record 45 of Set 9 | newington
# Processing Record 46 of Set 9 | neiafu
# Processing Record 47 of Set 9 | casper
# Processing Record 48 of Set 9 | lai
# Processing Record 49 of Set 9 | oktyabrskoye
# Processing Record 50 of Set 9 | lata
# Processing Record 1 of Set 10 | baykit
# Processing Record 2 of Set 10 | solofra
# Processing Record 3 of Set 10 | nemuro
# Processing Record 4 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 5 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 10 | lebu
# Processing Record 7 of Set 10 | surskoye
# Processing Record 8 of Set 10 | chimbote
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | severnoye
# Processing Record 11 of Set 10 | aksaray
# Processing Record 12 of Set 10 | selikhino
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | kruisfontein
# Processing Record 15 of Set 10 | grevesmuhlen
# Processing Record 16 of Set 10 | inuvik
# Processing Record 17 of Set 10 | kendari
# Processing Record 18 of Set 10 | melendugno
# Processing Record 19 of Set 10 | brokopondo
# Processing Record 20 of Set 10 | esperance
# Processing Record 21 of Set 10 | itoman
# Processing Record 22 of Set 10 | san andres
# Processing Record 23 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 24 of Set 10 | siocon
# Processing Record 25 of Set 10 | kloulklubed
# Processing Record 26 of Set 10 | tura
# Processing Record 27 of Set 10 | santa rosa
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | iskateley
# Processing Record 30 of Set 10 | starobaltachevo
# Processing Record 31 of Set 10 | narasaraopet
# Processing Record 32 of Set 10 | masunga
# Processing Record 33 of Set 10 | letlhakane
# Processing Record 34 of Set 10 | khani
# Processing Record 35 of Set 10 | lyaskelya
# Processing Record 36 of Set 10 | anaco
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | aloleng
# Processing Record 39 of Set 10 | morehead
# Processing Record 40 of Set 10 | arbazh
# Processing Record 41 of Set 10 | qasigiannguit
# Processing Record 42 of Set 10 | ziro
# Processing Record 43 of Set 10 | inirida
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | ondjiva
# Processing Record 46 of Set 10 | muleba
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | nortelandia
# Processing Record 49 of Set 10 | puli
# Processing Record 50 of Set 10 | chokurdakh
# Processing Record 1 of Set 11 | kiunga
# Processing Record 2 of Set 11 | marienburg
# Processing Record 3 of Set 11 | mukhen
# Processing Record 4 of Set 11 | sol-iletsk
# Processing Record 5 of Set 11 | chardara
# Processing Record 6 of Set 11 | ortega
# Processing Record 7 of Set 11 | mount isa
# Processing Record 8 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 11 | brantford
# Processing Record 10 of Set 11 | jalu
# Processing Record 11 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 11 | shagonar
# Processing Record 13 of Set 11 | kutum
# Processing Record 14 of Set 11 | puebloviejo
# Processing Record 15 of Set 11 | port-gentil
# Processing Record 16 of Set 11 | fairbanks
# Processing Record 17 of Set 11 | paracuru
# Processing Record 18 of Set 11 | sorong
# Processing Record 19 of Set 11 | namtsy
# Processing Record 20 of Set 11 | kjollefjord
# Processing Record 21 of Set 11 | lundazi
# Processing Record 22 of Set 11 | bowen
# Processing Record 23 of Set 11 | livingston
# Processing Record 24 of Set 11 | klyuchi
# Processing Record 25 of Set 11 | yerbogachen
# Processing Record 26 of Set 11 | kalmunai
# Processing Record 27 of Set 11 | troitsko-pechorsk
# Processing Record 28 of Set 11 | soto la marina
# Processing Record 29 of Set 11 | teyateyaneng
# Processing Record 30 of Set 11 | atar
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | vuktyl
# Processing Record 33 of Set 11 | srednekolymsk
# Processing Record 34 of Set 11 | urecheni
# Processing Record 35 of Set 11 | jonava
# Processing Record 36 of Set 11 | jamame
# Processing Record 37 of Set 11 | los llanos de aridane
# Processing Record 38 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 39 of Set 11 | arlington
# Processing Record 40 of Set 11 | bawku
# Processing Record 41 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 11 | burica
# City not found. Skipping...
# Processing Record 43 of Set 11 | deputatskiy
# Processing Record 44 of Set 11 | vanavara
# Processing Record 45 of Set 11 | sioux lookout
# Processing Record 46 of Set 11 | castro
# Processing Record 47 of Set 11 | valdivia
# Processing Record 48 of Set 11 | witu
# Processing Record 49 of Set 11 | saint-francois
# Processing Record 50 of Set 11 | rafaela
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | trairi
# Processing Record 3 of Set 12 | chadiza
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | lagoa
# Processing Record 6 of Set 12 | onega
# Processing Record 7 of Set 12 | kazanskaya
# Processing Record 8 of Set 12 | inhambane
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | conakry
# Processing Record 11 of Set 12 | tambilil
# Processing Record 12 of Set 12 | manokwari
# Processing Record 13 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 12 | de-kastri
# Processing Record 15 of Set 12 | sao miguel do araguaia
# Processing Record 16 of Set 12 | musoma
# Processing Record 17 of Set 12 | le mars
# Processing Record 18 of Set 12 | ruidoso
# Processing Record 19 of Set 12 | cayenne
# Processing Record 20 of Set 12 | katobu
# Processing Record 21 of Set 12 | talcahuano
# Processing Record 22 of Set 12 | hollins
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | ballater
# Processing Record 25 of Set 12 | tommot
# Processing Record 26 of Set 12 | horadiz
# Processing Record 27 of Set 12 | auki
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | malanje
# Processing Record 30 of Set 12 | meulaboh
# Processing Record 31 of Set 12 | lianran
# Processing Record 32 of Set 12 | hammerfest
# Processing Record 33 of Set 12 | belfast
# Processing Record 34 of Set 12 | mareeba
# Processing Record 35 of Set 12 | matiri
# Processing Record 36 of Set 12 | antalaha
# Processing Record 37 of Set 12 | murgeni
# Processing Record 38 of Set 12 | quang ngai
# Processing Record 39 of Set 12 | voznesenye
# Processing Record 40 of Set 12 | turukhansk
# Processing Record 41 of Set 12 | suzhou
# Processing Record 42 of Set 12 | camaqua
# Processing Record 43 of Set 12 | rayon
# Processing Record 44 of Set 12 | salinas
# Processing Record 45 of Set 12 | tigzirt
# Processing Record 46 of Set 12 | gasa
# Processing Record 47 of Set 12 | kampong thum
# Processing Record 48 of Set 12 | karaton
# Processing Record 49 of Set 12 | glens falls
# Processing Record 50 of Set 12 | lichinga
# Processing Record 1 of Set 13 | hamilton
# Processing Record 2 of Set 13 | kaduna
# Processing Record 3 of Set 13 | caen
# Processing Record 4 of Set 13 | aldama
# Processing Record 5 of Set 13 | saint john
# Processing Record 6 of Set 13 | vredendal
# Processing Record 7 of Set 13 | dunda
# Processing Record 8 of Set 13 | goderich
# Processing Record 9 of Set 13 | alexandria
# Processing Record 10 of Set 13 | kyshtovka
# Processing Record 11 of Set 13 | shirokiy
# Processing Record 12 of Set 13 | sabang
# Processing Record 13 of Set 13 | pontianak
# Processing Record 14 of Set 13 | tupik
# Processing Record 15 of Set 13 | kosgi
# City not found. Skipping...
# Processing Record 16 of Set 13 | mezen
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | teguise
# Processing Record 19 of Set 13 | boma
# Processing Record 20 of Set 13 | nabire
# Processing Record 21 of Set 13 | kyra
# Processing Record 22 of Set 13 | gopalur
# Processing Record 23 of Set 13 | pemangkat
# Processing Record 24 of Set 13 | maltahohe
# Processing Record 25 of Set 13 | amahai
# Processing Record 26 of Set 13 | telma
# Processing Record 27 of Set 13 | matara
# Processing Record 28 of Set 13 | senanga
# Processing Record 29 of Set 13 | roma
# Processing Record 30 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 13 | itambacuri
# Processing Record 32 of Set 13 | damara
# Processing Record 33 of Set 13 | yar-sale
# Processing Record 34 of Set 13 | oum hadjer
# Processing Record 35 of Set 13 | rzhaksa
# Processing Record 36 of Set 13 | skjervoy
# Processing Record 37 of Set 13 | bengkulu
# Processing Record 38 of Set 13 | bukama
# Processing Record 39 of Set 13 | lincoln
# Processing Record 40 of Set 13 | marktoberdorf
# Processing Record 41 of Set 13 | kudahuvadhoo
# Processing Record 42 of Set 13 | shache
# Processing Record 43 of Set 13 | puerto colombia
# Processing Record 44 of Set 13 | lima
# Processing Record 45 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 13 | plymouth
# Processing Record 47 of Set 13 | mangochi
# Processing Record 48 of Set 13 | springbok
# Processing Record 49 of Set 13 | elizabeth city
# Processing Record 50 of Set 13 | sokoto
# Processing Record 1 of Set 14 | quesnel
# Processing Record 2 of Set 14 | valparaiso
# Processing Record 3 of Set 14 | nanakuli
# Processing Record 4 of Set 14 | praia da vitoria
# Processing Record 5 of Set 14 | christchurch
# Processing Record 6 of Set 14 | pula
# Processing Record 7 of Set 14 | yamethin
# Processing Record 8 of Set 14 | canyon
# Processing Record 9 of Set 14 | erzin
# Processing Record 10 of Set 14 | willowmore
# Processing Record 11 of Set 14 | vakhtan
# Processing Record 12 of Set 14 | dubai
# Processing Record 13 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 14 | arvika
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | keuruu
# Processing Record 17 of Set 14 | labuhan
# Processing Record 18 of Set 14 | mandalgovi
# Processing Record 19 of Set 14 | bongandanga
# Processing Record 20 of Set 14 | medicine hat
# Processing Record 21 of Set 14 | porto novo
# Processing Record 22 of Set 14 | axim
# Processing Record 23 of Set 14 | hovd
# Processing Record 24 of Set 14 | mme
# City not found. Skipping...
# Processing Record 25 of Set 14 | bagdarin
# Processing Record 26 of Set 14 | san isidro
# Processing Record 27 of Set 14 | hue
# Processing Record 28 of Set 14 | alamogordo
# Processing Record 29 of Set 14 | contadero
# Processing Record 30 of Set 14 | pasni
# Processing Record 31 of Set 14 | tectitan
# City not found. Skipping...
# Processing Record 32 of Set 14 | sovetskiy
# Processing Record 33 of Set 14 | artvin
# Processing Record 34 of Set 14 | pacific grove
# Processing Record 35 of Set 14 | tibati
# Processing Record 36 of Set 14 | fougamou
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | ailigandi
# Processing Record 39 of Set 14 | sao cristovao
# Processing Record 40 of Set 14 | yafran
# Processing Record 41 of Set 14 | abu dhabi
# Processing Record 42 of Set 14 | kaliua
# Processing Record 43 of Set 14 | jiuquan
# Processing Record 44 of Set 14 | san quintin
# Processing Record 45 of Set 14 | pontes e lacerda
# Processing Record 46 of Set 14 | odweyne
# Processing Record 47 of Set 14 | tazmalt
# Processing Record 48 of Set 14 | caconda
# Processing Record 49 of Set 14 | anadyr
# Processing Record 50 of Set 14 | sao jose da coroa grande
# Processing Record 1 of Set 15 | taitung
# Processing Record 2 of Set 15 | coshocton
# Processing Record 3 of Set 15 | polignano a mare
# Processing Record 4 of Set 15 | manta
# Processing Record 5 of Set 15 | usinsk
# Processing Record 6 of Set 15 | buseresere
# Processing Record 7 of Set 15 | derzhavinsk
# Processing Record 8 of Set 15 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 15 | do gonbadan
# Processing Record 10 of Set 15 | mazagao
# Processing Record 11 of Set 15 | mocuba
# Processing Record 12 of Set 15 | porto santo
# Processing Record 13 of Set 15 | yalova
# Processing Record 14 of Set 15 | avanigadda
# Processing Record 15 of Set 15 | lebowakgomo
# Processing Record 16 of Set 15 | eyl
# Processing Record 17 of Set 15 | zitiste
# Processing Record 18 of Set 15 | payson
# Processing Record 19 of Set 15 | lamar
# Processing Record 20 of Set 15 | mogadishu
# Processing Record 21 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 15 | tefe
# Processing Record 23 of Set 15 | codrington
# Processing Record 24 of Set 15 | spremberg
# Processing Record 25 of Set 15 | bonthe
# Processing Record 26 of Set 15 | nusaybin
# Processing Record 27 of Set 15 | gamba
# Processing Record 28 of Set 15 | khvoynaya
# Processing Record 29 of Set 15 | kanye
# Processing Record 30 of Set 15 | solnechnyy
# Processing Record 31 of Set 15 | saint-augustin
# Processing Record 32 of Set 15 | ferme-neuve
# Processing Record 33 of Set 15 | arkhara
# Processing Record 34 of Set 15 | batamshinskiy
# Processing Record 35 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 15 | erdenet
# Processing Record 37 of Set 15 | rio cuarto
# Processing Record 38 of Set 15 | kashi
# Processing Record 39 of Set 15 | guatire
# Processing Record 40 of Set 15 | salem
# Processing Record 41 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 15 | santa cruz
# Processing Record 43 of Set 15 | lapeer
# Processing Record 44 of Set 15 | luanda
# Processing Record 45 of Set 15 | burnie
# Processing Record 46 of Set 15 | sonoita
# Processing Record 47 of Set 15 | kupang
# Processing Record 48 of Set 15 | santa maria
# Processing Record 49 of Set 15 | grimshaw
# Processing Record 50 of Set 15 | nsanje
# Processing Record 1 of Set 16 | mungaoli
# Processing Record 2 of Set 16 | mangrol
# Processing Record 3 of Set 16 | poltava
# Processing Record 4 of Set 16 | bathsheba
# Processing Record 5 of Set 16 | gravdal
# Processing Record 6 of Set 16 | skagen
# Processing Record 7 of Set 16 | talara
# Processing Record 8 of Set 16 | nuevo progreso
# Processing Record 9 of Set 16 | aberdeen
# Processing Record 10 of Set 16 | taiyuan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Port Lincoln      AU -34.7333  135.8667     59.52        51
# 1                 Brainerd      US  46.3580  -94.2008     37.18        93
# 2                     Naze      JP  28.3667  129.4833     76.12        62
# 3               Caluquembe      AO -13.7833   14.6833     62.02        84
# 4                   Harper      LR   4.3750   -7.7169     77.02        85
# 5                Marystown      CA  47.1666  -55.1483     42.85       100
# 6           Virginia Beach      US  36.8529  -75.9780     63.01        74
# 7             Gualeguaychu      AR -33.0094  -58.5172     72.86        76
# 8          Arraial Do Cabo      BR -22.9661  -42.0278     69.08        88
# 9  San Carlos De Bariloche      AR -41.1456  -71.3082     43.57        92
#
#    Cloudiness  Wind Speed Current Description
# 0          35        8.28    scattered clouds
# 1           1        0.00           clear sky
# 2          92        9.13     overcast clouds
# 3          98        1.52     overcast clouds
# 4         100        5.75     overcast clouds
# 5          97        1.01     overcast clouds
# 6           1        5.99           clear sky
# 7           1       10.38           clear sky
# 8         100       14.65     overcast clouds
# 9           6        5.46           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
